# %% [markdown]
# ## New workflow

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = 90

# %%
hospital_data = pd.read_csv('data01.csv')
hospital_data.head(100)
# Out:
#     group      ID  outcome  age  gendera        BMI  hypertensive  \
# 0       1  125047      0.0   72        1  37.588179             0
# 1       1  139812      0.0   75        2        NaN             0
# 2       1  109787      0.0   83        2  26.572634             0
# 3       1  130587      0.0   43        2  83.264629             0
# 4       1  138290      0.0   75        2  31.824842             1
# ..    ...     ...      ...  ...      ...        ...           ...
# 95      1  152651      0.0   94        1  26.224800             1
# 96      1  128156      0.0   70        1  25.662222             0
# 97      1  108287      0.0   63        2  37.261470             1
# 98      1  135809      0.0   68        1  34.527089             1
# 99      1  121435      0.0   88        1  14.858018             1
#
#     atrialfibrillation  CHD with no MI  diabetes  deficiencyanemias  \
# 0                    0               0         1                  1
# ...

# %%
# hospital_data.drop('ID', axis=1,inplace=True)
# hospital_data.drop('group', axis=1,inplace=True)

# %%
hospital_data
# Out:
#       outcome  age  gendera          BMI  hypertensive  atrialfibrillation  \
# 0         0.0   72        1    37.588179             0                   0
# 1         0.0   75        2  1899.276512             0                   0
# 2         0.0   83        2    26.572634             0                   0
# 3         0.0   43        2    83.264629             0                   0
# 4         0.0   75        2    31.824842             1                   0
# ...       ...  ...      ...          ...           ...                 ...
# 1172      0.0   62        1    25.516870             1                   1
# 1173      0.0   78        1    25.822710             0                   1
# 1174      0.0   85        2    23.891779             1                   1
# 1175      0.0   79        2    35.288554             0                   0
# 1176      0.0   47        1    23.121384             1                   0
#
# ...

# %%
hospital_data.describe()
# Out:
#            outcome          age      gendera          BMI  hypertensive  \
# count  1176.000000  1176.000000  1176.000000  1176.000000   1176.000000
# mean      0.135204    74.047619     1.525510   370.311477      0.717687
# std       0.342087    13.437241     0.499561   721.491647      0.450316
# min       0.000000    19.000000     1.000000    13.346801      0.000000
# 25%       0.000000    65.000000     1.000000    25.274510      0.000000
# 50%       0.000000    77.000000     2.000000    30.369531      1.000000
# 75%       0.000000    85.000000     2.000000    42.178658      1.000000
# max       1.000000    99.000000     2.000000  1899.276512      1.000000
#
#        atrialfibrillation  CHD with no MI     diabetes  deficiencyanemias  \
# count         1176.000000     1176.000000  1176.000000        1176.000000
# mean             0.451531        0.085884     0.420918           0.339286
# std              0.497857        0.280312     0.493917           0.473668
# ...

# %%
hospital_data.isna().sum()
# Out:
# outcome                      0
# age                          0
# gendera                      0
# BMI                          0
# hypertensive                 0
# atrialfibrillation           0
# CHD with no MI               0
# diabetes                     0
# deficiencyanemias            0
# depression                   0
# Hyperlipemia                 0
# Renal failure                0
# COPD                         0
# heart rate                   0
# Systolic blood pressure      0
# Diastolic blood pressure     0
# Respiratory rate             0
# temperature                  0
# SP O2                        0
# Urine output                35
# hematocrit                   0
# RBC                          0
# MCH                          0
# MCHC                         0
# MCV                          0
# RDW                          0
# Leucocyte                    0
# Platelets                    0
# Neutrophils                  0
# Basophils                    0
# ...

# %%
hospital_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1176 entries, 0 to 1176
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   outcome                   1176 non-null   float64
#  1   age                       1176 non-null   int64
#  2   gendera                   1176 non-null   int64
#  3   BMI                       1176 non-null   float64
#  4   hypertensive              1176 non-null   int64
#  5   atrialfibrillation        1176 non-null   int64
#  6   CHD with no MI            1176 non-null   int64
#  7   diabetes                  1176 non-null   int64
#  8   deficiencyanemias         1176 non-null   int64
#  9   depression                1176 non-null   int64
#  10  Hyperlipemia              1176 non-null   int64
#  11  Renal failure             1176 non-null   int64
#  12  COPD                      1176 non-null   int64
#  13  heart rate                1176 non-null   float64
# ...

# %%
hospital_data.outcome.value_counts()
# Out:
# 0.0    1017
# 1.0     159
# Name: outcome, dtype: int64

# %%
hospital_data.outcome.value_counts().plot(kind='bar', color=['green', 'cyan'])
# Out:
# <AxesSubplot:>

# %%
pd.crosstab(hospital_data.gendera, hospital_data.outcome)
# Out:
# outcome  0.0  1.0
# gendera
# 1        478   80
# 2        539   79

# %%
hospital_data['Urine output'].value_counts()
# Out:
# 2155.0    6
# 1305.0    6
# 930.0     5
# 860.0     5
# 1495.0    5
#          ..
# 2870.0    1
# 978.0     1
# 1925.0    1
# 2855.0    1
# 118.0     1
# Name: Urine output, Length: 810, dtype: int64

# %%
hospital_data['hematocrit'].plot(style='.')
# Out:
# <AxesSubplot:>

# %%
hospital_data.age.plot(kind='hist', bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Lets fill the missing numbers with the mean

# %%
from sklearn.impute import SimpleImputer
# from sklearn.compose import ColumnTransformer

# %%
fill = SimpleImputer(strategy='mean')
columns = ['Urine Output']

imputer = fill.fit_transform(hospital_data)

# %%
hospital_data.isna().sum()
# Out:
# outcome                      0
# age                          0
# gendera                      0
# BMI                          0
# hypertensive                 0
# atrialfibrillation           0
# CHD with no MI               0
# diabetes                     0
# deficiencyanemias            0
# depression                   0
# Hyperlipemia                 0
# Renal failure                0
# COPD                         0
# heart rate                   0
# Systolic blood pressure      0
# Diastolic blood pressure     0
# Respiratory rate             0
# temperature                  0
# SP O2                        0
# Urine output                35
# hematocrit                   0
# RBC                          0
# MCH                          0
# MCHC                         0
# MCV                          0
# RDW                          0
# Leucocyte                    0
# Platelets                    0
# Neutrophils                  0
# Basophils                    0
# ...

# %%
hospital_data['BMI'].fillna(hospital_data['Urine output'].mean(), inplace=True)

# %%
def fill(a):
    c = a.fillna(a.mean(), inplace=True)
    return c

fill(hospital_data['PCO2'])
fill(hospital_data['Lactic acid'])
fill(hospital_data['PH'])
fill(hospital_data['Blood calcium'])
fill(hospital_data['glucose'])
fill(hospital_data['Creatine kinase'])
fill(hospital_data['INR'])
fill(hospital_data['PT'])
fill(hospital_data['Lymphocyte'])
fill(hospital_data['Basophils'])
fill(hospital_data['Neutrophils'])
fill(hospital_data['SP O2'])
fill(hospital_data['temperature'])
fill(hospital_data['Respiratory rate'])
fill(hospital_data['Diastolic blood pressure'])
fill(hospital_data['heart rate'])
fill(hospital_data['Systolic blood pressure'])

# %%
hospital_data.dropna(subset='outcome', inplace=True)

# %%
hospital_data
# Out:
#       outcome  age  gendera          BMI  hypertensive  atrialfibrillation  \
# 0         0.0   72        1    37.588179             0                   0
# 1         0.0   75        2  1899.276512             0                   0
# 2         0.0   83        2    26.572634             0                   0
# 3         0.0   43        2    83.264629             0                   0
# 4         0.0   75        2    31.824842             1                   0
# ...       ...  ...      ...          ...           ...                 ...
# 1172      0.0   62        1    25.516870             1                   1
# 1173      0.0   78        1    25.822710             0                   1
# 1174      0.0   85        2    23.891779             1                   1
# 1175      0.0   79        2    35.288554             0                   0
# 1176      0.0   47        1    23.121384             1                   0
#
# ...

# %%
hospital_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1176 entries, 0 to 1176
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   outcome                   1176 non-null   float64
#  1   age                       1176 non-null   int64
#  2   gendera                   1176 non-null   int64
#  3   BMI                       1176 non-null   float64
#  4   hypertensive              1176 non-null   int64
#  5   atrialfibrillation        1176 non-null   int64
#  6   CHD with no MI            1176 non-null   int64
#  7   diabetes                  1176 non-null   int64
#  8   deficiencyanemias         1176 non-null   int64
#  9   depression                1176 non-null   int64
#  10  Hyperlipemia              1176 non-null   int64
#  11  Renal failure             1176 non-null   int64
#  12  COPD                      1176 non-null   int64
#  13  heart rate                1176 non-null   float64
# ...

# %%
plt.scatter(hospital_data.age[hospital_data.outcome==1],
           hospital_data['Urine output'][hospital_data.outcome==1],
           c='green', alpha=1)
plt.scatter(hospital_data.age[hospital_data.outcome==0],
           hospital_data['Urine output'][hospital_data.outcome==0],
           c='blue', alpha=0.2)
plt.legend(['dead', 'alive'])
plt.xlabel('Age')
plt.ylabel('Urine Output')
plt.title('Age against Urine Sample');

# %% [markdown]
# # CheckPoint

# %%
data = hospital_data.copy()

# %%
data
# Out:
#       outcome  age  gendera          BMI  hypertensive  atrialfibrillation  \
# 0         0.0   72        1    37.588179             0                   0
# 1         0.0   75        2  1899.276512             0                   0
# 2         0.0   83        2    26.572634             0                   0
# 3         0.0   43        2    83.264629             0                   0
# 4         0.0   75        2    31.824842             1                   0
# ...       ...  ...      ...          ...           ...                 ...
# 1172      0.0   62        1    25.516870             1                   1
# 1173      0.0   78        1    25.822710             0                   1
# 1174      0.0   85        2    23.891779             1                   1
# 1175      0.0   79        2    35.288554             0                   0
# 1176      0.0   47        1    23.121384             1                   0
#
# ...

# %%
data['Urine output'].describe()
# Out:
# count    1141.000000
# mean     1899.276512
# std      1272.363631
# min         0.000000
# 25%       980.000000
# 50%      1675.000000
# 75%      2500.000000
# max      8820.000000
# Name: Urine output, dtype: float64

# %%
def sam(a):
    sorted_col = a.sort_values()
    per = sorted_col.quantile(0.8)
    fil = sorted_col[sorted_col <= per]
    return fil

# %%
plaT = sam(data.Platelets)

# %%
Leucocyte = sam(data.Leucocyte)
Basophils =sam(data.Basophils)
Lymphocyte = sam(data.Lymphocyte)
PT = sam(data.PT)
INR = sam(data.INR)
Creatinine = sam(data.Creatinine)
Urineoutput = sam(data['Urine output'])
creatineKinase = (data['Creatine kinase'])
NTproBNP = sam(data['NT-proBNP'])
Ureanitrogen = sam(data['Urea nitrogen'])
Lacticacid = sam(data['Lactic acid'])

# %%
Leucocyte
# Out:
# 1099     0.100000
# 803      0.330000
# 1119     0.612500
# 20       0.881818
# 172      1.140000
#           ...
# 556     13.550000
# 639     13.570588
# 935     13.612500
# 1165    13.622222
# 766     13.625000
# Name: Leucocyte, Length: 941, dtype: float64

# %%
data.describe()
# Out:
#            outcome          age      gendera          BMI  hypertensive  \
# count  1176.000000  1176.000000  1176.000000  1176.000000   1176.000000
# mean      0.135204    74.047619     1.525510   370.311477      0.717687
# std       0.342087    13.437241     0.499561   721.491647      0.450316
# min       0.000000    19.000000     1.000000    13.346801      0.000000
# 25%       0.000000    65.000000     1.000000    25.274510      0.000000
# 50%       0.000000    77.000000     2.000000    30.369531      1.000000
# 75%       0.000000    85.000000     2.000000    42.178658      1.000000
# max       1.000000    99.000000     2.000000  1899.276512      1.000000
#
#        atrialfibrillation  CHD with no MI     diabetes  deficiencyanemias  \
# count         1176.000000     1176.000000  1176.000000        1176.000000
# mean             0.451531        0.085884     0.420918           0.339286
# std              0.497857        0.280312     0.493917           0.473668
# ...

# %%
data.drop('Leucocyte', axis=1, inplace=True)

# %%
data['Leucocyte'] = Leucocyte

# %%
data['Basophils'] = Basophils

# %%
data.describe()
# Out:
#            outcome          age      gendera          BMI  hypertensive  \
# count  1176.000000  1176.000000  1176.000000  1176.000000   1176.000000
# mean      0.135204    74.047619     1.525510   370.311477      0.717687
# std       0.342087    13.437241     0.499561   721.491647      0.450316
# min       0.000000    19.000000     1.000000    13.346801      0.000000
# 25%       0.000000    65.000000     1.000000    25.274510      0.000000
# 50%       0.000000    77.000000     2.000000    30.369531      1.000000
# 75%       0.000000    85.000000     2.000000    42.178658      1.000000
# max       1.000000    99.000000     2.000000  1899.276512      1.000000
#
#        atrialfibrillation  CHD with no MI     diabetes  deficiencyanemias  \
# count         1176.000000     1176.000000  1176.000000        1176.000000
# mean             0.451531        0.085884     0.420918           0.339286
# std              0.497857        0.280312     0.493917           0.473668
# ...

# %%
data['Lymphocyte'] = Lymphocyte

# %%
data['Urine output'] = Urineoutput

# %%
Leucocyte = sam(data.Leucocyte)
Basophils =sam(data.Basophils)
Lymphocyte = sam(data.Lymphocyte)
PT = sam(data.PT)
INR = sam(data.INR)
Creatinine = sam(data.Creatinine)
Urineoutput = sam(data['Urine output'])
creatineKinase = (data['Creatine kinase'])
NTproBNP = sam(data['NT-proBNP'])
Ureanitrogen = sam(data['Urea nitrogen'])
Lacticacid = sam(data['Lactic acid'])

# %%
data['Urea nitrogen'] = Ureanitrogen

# %%
data['PT'] = PT

# %%
data['INR'] = INR

# %%
data['Creatinine'] = Creatinine

# %%
data['Creatine kinase'] = creatineKinase

# %%
data['NT-proBNP'] = NTproBNP

# %%
data['Lactic acid'] = Lacticacid

# %%
data['Platelets'] = plaT

# %%
data.isna().sum()
# Out:
# outcome                       0
# age                           0
# gendera                       0
# BMI                           0
# hypertensive                  0
# atrialfibrillation            0
# CHD with no MI                0
# diabetes                      0
# deficiencyanemias             0
# depression                    0
# Hyperlipemia                  0
# Renal failure                 0
# COPD                          0
# heart rate                    0
# Systolic blood pressure       0
# Diastolic blood pressure      0
# Respiratory rate              0
# temperature                   0
# SP O2                         0
# Urine output                263
# hematocrit                    0
# RBC                           0
# MCH                           0
# MCHC                          0
# MCV                           0
# RDW                           0
# Platelets                   235
# Neutrophils                   0
# Basophils                   192
# ...

# %%
data.describe()
# Out:
#            outcome          age      gendera          BMI  hypertensive  \
# count  1176.000000  1176.000000  1176.000000  1176.000000   1176.000000
# mean      0.135204    74.047619     1.525510   370.311477      0.717687
# std       0.342087    13.437241     0.499561   721.491647      0.450316
# min       0.000000    19.000000     1.000000    13.346801      0.000000
# 25%       0.000000    65.000000     1.000000    25.274510      0.000000
# 50%       0.000000    77.000000     2.000000    30.369531      1.000000
# 75%       0.000000    85.000000     2.000000    42.178658      1.000000
# max       1.000000    99.000000     2.000000  1899.276512      1.000000
#
#        atrialfibrillation  CHD with no MI     diabetes  deficiencyanemias  \
# count         1176.000000     1176.000000  1176.000000        1176.000000
# mean             0.451531        0.085884     0.420918           0.339286
# std              0.497857        0.280312     0.493917           0.473668
# ...

# %%
creatineKinase = sam(data['Creatine kinase'])

# %%
data['Creatine kinase'] = creatineKinase

# %%
data.describe()
# Out:
#            outcome          age      gendera          BMI  hypertensive  \
# count  1176.000000  1176.000000  1176.000000  1176.000000   1176.000000
# mean      0.135204    74.047619     1.525510   370.311477      0.717687
# std       0.342087    13.437241     0.499561   721.491647      0.450316
# min       0.000000    19.000000     1.000000    13.346801      0.000000
# 25%       0.000000    65.000000     1.000000    25.274510      0.000000
# 50%       0.000000    77.000000     2.000000    30.369531      1.000000
# 75%       0.000000    85.000000     2.000000    42.178658      1.000000
# max       1.000000    99.000000     2.000000  1899.276512      1.000000
#
#        atrialfibrillation  CHD with no MI     diabetes  deficiencyanemias  \
# count         1176.000000     1176.000000  1176.000000        1176.000000
# mean             0.451531        0.085884     0.420918           0.339286
# std              0.497857        0.280312     0.493917           0.473668
# ...

# %%
data.isna().sum()
# Out:
# outcome                       0
# age                           0
# gendera                       0
# BMI                           0
# hypertensive                  0
# atrialfibrillation            0
# CHD with no MI                0
# diabetes                      0
# deficiencyanemias             0
# depression                    0
# Hyperlipemia                  0
# Renal failure                 0
# COPD                          0
# heart rate                    0
# Systolic blood pressure       0
# Diastolic blood pressure      0
# Respiratory rate              0
# temperature                   0
# SP O2                         0
# Urine output                263
# hematocrit                    0
# RBC                           0
# MCH                           0
# MCHC                          0
# MCV                           0
# RDW                           0
# Platelets                   235
# Neutrophils                   0
# Basophils                   192
# ...

# %%
def fill(a):
    c = a.fillna(a.mean(), inplace=True)
    return c

fill(data['Lactic acid'])
fill(data['PT'])
fill(data['NT-proBNP'])
fill(data['Creatinine'])
fill(data['Creatine kinase'])
fill(data['INR'])
fill(data['Platelets'])
fill(data['Lymphocyte'])
fill(data['Basophils'])
fill(data['Urine output'])
fill(data['Leucocyte'])
fill(data['Urea nitrogen'])

# %%
data.isna().sum()
# Out:
# outcome                     0
# age                         0
# gendera                     0
# BMI                         0
# hypertensive                0
# atrialfibrillation          0
# CHD with no MI              0
# diabetes                    0
# deficiencyanemias           0
# depression                  0
# Hyperlipemia                0
# Renal failure               0
# COPD                        0
# heart rate                  0
# Systolic blood pressure     0
# Diastolic blood pressure    0
# Respiratory rate            0
# temperature                 0
# SP O2                       0
# Urine output                0
# hematocrit                  0
# RBC                         0
# MCH                         0
# MCHC                        0
# MCV                         0
# RDW                         0
# Platelets                   0
# Neutrophils                 0
# Basophils                   0
# Lymphocyte                  0
# PT                          0
# ...

# %%
perfect_data = data.copy()

# %%
perfect_data.to_csv('ready to model', index=False)

# %% [markdown]
# ## Time to Run Our Machine Learning Model

# %%
data = pd.read_csv('ready to model')

# %%
data
# Out:
#       outcome  age  gendera          BMI  hypertensive  atrialfibrillation  \
# 0         0.0   72        1    37.588179             0                   0
# 1         0.0   75        2  1899.276512             0                   0
# 2         0.0   83        2    26.572634             0                   0
# 3         0.0   43        2    83.264629             0                   0
# 4         0.0   75        2    31.824842             1                   0
# ...       ...  ...      ...          ...           ...                 ...
# 1171      0.0   62        1    25.516870             1                   1
# 1172      0.0   78        1    25.822710             0                   1
# 1173      0.0   85        2    23.891779             1                   1
# 1174      0.0   79        2    35.288554             0                   0
# 1175      0.0   47        1    23.121384             1                   0
#
# ...

# %%
data.describe()
# Out:
#            outcome          age      gendera          BMI  hypertensive  \
# count  1176.000000  1176.000000  1176.000000  1176.000000   1176.000000
# mean      0.135204    74.047619     1.525510   370.311477      0.717687
# std       0.342087    13.437241     0.499561   721.491647      0.450316
# min       0.000000    19.000000     1.000000    13.346801      0.000000
# 25%       0.000000    65.000000     1.000000    25.274510      0.000000
# 50%       0.000000    77.000000     2.000000    30.369531      1.000000
# 75%       0.000000    85.000000     2.000000    42.178658      1.000000
# max       1.000000    99.000000     2.000000  1899.276512      1.000000
#
#        atrialfibrillation  CHD with no MI     diabetes  deficiencyanemias  \
# count         1176.000000     1176.000000  1176.000000        1176.000000
# mean             0.451531        0.085884     0.420918           0.339286
# std              0.497857        0.280312     0.493917           0.473668
# ...

# %%
data.drop('BMI', axis=1, inplace=True)

# %%
data
# Out:
#       outcome  age  gendera  hypertensive  atrialfibrillation  CHD with no MI  \
# 0         0.0   72        1             0                   0               0
# 1         0.0   75        2             0                   0               0
# 2         0.0   83        2             0                   0               0
# 3         0.0   43        2             0                   0               0
# 4         0.0   75        2             1                   0               0
# ...       ...  ...      ...           ...                 ...             ...
# 1171      0.0   62        1             1                   1               0
# 1172      0.0   78        1             0                   1               0
# 1173      0.0   85        2             1                   1               0
# 1174      0.0   79        2             0                   0               1
# 1175      0.0   47        1             1                   0               0
#
# ...

# %%
correrated_data = data.corr()

# %%
fig, ax = plt.subplots(figsize=(50,50))
ax = sns.heatmap(correrated_data, annot=True, fmt='.2f', cmap='crest')
